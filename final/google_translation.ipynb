# %%
from googletrans import Translator

# %%
import pandas as pd

# %%
df = pd.read_csv('marathi_tweets.csv')

# %%
df.values.tolist()[0]
# Out:
# ['कोरोना विरोधातील लढाईत भारताला रशियाची मदत, अमेरिकेनेही रवाना केलं विमान https://t.co/g6hzvCz8cz  @narendramodi']

# %%
translator = Translator()
translatedlist = [translator.translate(tweet[0], dest="en").text for tweet in df.values.tolist()]

# %%
print(translatedlist)
# Out:
# ['Russia helps India in Corona war, US sends plane https://t.co/g6hzvCz8cz arenarendramodi', "Husband's health deteriorates, doctor's wife gives oxygen from AC's air https://t.co/GCykKFHP8q", 'BJP leader Pankaja Munde infected with corona https://t.co/SxVkOG2J6l\r\n\r\nPankajamunde @ dhananjay_munde… https://t.co/8c7AkgB4ju', 'BJP leader Pankaja Munde infected with corona! - https://t.co/ZsQda8oD7z\r\nAnPankajamunde #Corona', 'News of Sangh Swayamsevak Narayan Dabhadkar vacating a bed for a 40-year-old patient went viral yesterday… https://t.co/hwZpEGnOOV', "Won't the false declarations of the Bhakas front stop? Just one year from May 2020. Due to this the Department of Health… https://t.co/O9ckSrFgCb", 'Congress Rajya Sabha MP Rajiv Satav is suffering from coronary heart disease.\r\nHttps: //t.co/LZsuuBzqhF… https://t.co/vjO78rXrum', 'More than 3,000 corona victims in India for the second day in a row\r\nhttps://t.co/ABt3yy5bWy\r\n\r\n#Corona #CoronaVirus # CoronaPandemic… https://t
# ...

# %%
tweets = pd.DataFrame(translatedlist)

# %%
tweets.to_csv('sheet1.csv',index=False)
